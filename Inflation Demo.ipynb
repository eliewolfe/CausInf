# %%
from __future__ import absolute_import

# %reload_ext autoreload
from igraph import Graph
import numpy as np
#import time
#from numba import njit
from scipy.sparse import coo_matrix, dok_matrix, csr_matrix
#from collections import defaultdict
#import json
import importlib

import os
os.environ['PYTHONUNBUFFERED'] = '1'

# %%
TriangleData=[0.12199995751046305, 0.0022969343799089472, 0.001748319476328954, 3.999015242496535e-05, 0.028907881434196828, 0.0005736087488455967, 0.0003924033706699725, 1.1247230369521505e-05, 0.0030142577390317635, 0.09234476010282468, 4.373922921480586e-05, 0.0014533921021948346, 0.0007798079722868244, 0.024091567451515063, 1.1247230369521505e-05, 0.0003849052170902915, 0.020774884184769502, 0.000396152447459813, 0.0003049249122403608, 4.998769053120669e-06, 0.10820335492385, 0.0020794879260981982, 0.0015546171755205281, 2.4993845265603346e-05, 0.0006260958239033638, 0.020273757587194154, 7.498153579681003e-06, 0.0003374169110856452, 0.0028942872817568676, 0.08976414557915113, 2.624353752888351e-05, 0.0012984302615480939, 0.002370666223442477, 4.7488306004646356e-05, 0.0999928767540993, 0.001957018084296742, 0.0006198473625869629, 8.747845842961171e-06, 0.02636975644747481, 0.0005198719815245496, 1.4996307159362007e-05, 0.000403650601039494, 0.0005498645958432735, 0.017359475229224805, 7.123245900696953e-05, 0.002346922070440154, 0.0033754188031197316, 0.10295964618712641, 0.00038740460161685187, 7.498153579681003e-06, 0.01608353942841575, 0.000306174604503641, 0.0021319750011559654, 4.248953695152569e-05, 0.09107007399427891, 0.001860791780024169, 5.998522863744803e-05, 0.0018395470115484063, 0.002570616985567304, 0.0766411271224461, 1.874538394920251e-05, 0.00048238121362614454, 0.0006410921310627258, 0.020223769896662948]
InstrumentalData=np.zeros(8);
InstrumentalData[0]=0.5;
InstrumentalData[5]=0.5;

inflation_order=2
TriangleGraph=Graph.Formula("X->A,Y->A:B,Z->B:C,X->C")
EvansGraph=Graph.Formula("U3->A:C:D,U2->B:C:D,U1->A:B,A->C,B->D")
InstrumentalGraph=Graph.Formula("U1->X->A->B,U2->A:B")
#We are going to need to get some code to work with variable ordering.

Graph=InstrumentalGraph
Data=InstrumentalData
card=2

#Graph=TriangleGraph
#Data=TriangleData
#card=4

# %%
from inflation.quickgraph import LearnSomeInflationGraphParameters
#importlib.reload(sys.modules['inflation.quickgraph'])
obs_count,num_vars,names=LearnSomeInflationGraphParameters(Graph,inflation_order)
[obs_count,num_vars,names]
# Out:
# [3, 10, ['X', 'A', 'B']]

# %%
from inflation.inflationmatrix import InflationMatrixFromGraph,FindB
importlib.reload(sys.modules['inflation.graphs'])
importlib.reload(sys.modules['inflation.inflationmatrix'])
SparseInflationMatrix = InflationMatrixFromGraph(Graph,inflation_order,card)
# Out:
# ['X', 'A', 'B']

# %%
SparseInflationMatrix.shape
# Out:
# (36, 156)

# %%
MarginalVector=FindB(Data,inflation_order)
[MarginalVector.shape,SparseInflationMatrix.shape]
# Out:
# [(36,), (36, 156)]

# %%
"""from lib.inflationlp import InflationLP
#importlib.reload(sys.modules['lib.inflationlp'])
Sol=InflationLP(TriangleSparseInflationMatrix,MarginalVector)""";

# %%
#
#import compileall
#import sys
#import importlib
#compileall.compile_file("lib\\moseklp.py",force=True)
#from lib.moseklp import InfeasibilityCertificate, InfeasibilityCertificateAUTO
#importlib.reload(sys.modules['lib.moseklp'])

from inflation.moseklp import InfeasibilityCertificate
from inflation.mosekinfeas import InfeasibilityCertificateAUTO

Sol=InfeasibilityCertificateAUTO(
    SparseInflationMatrix,
    MarginalVector)
# Out:
# Inferred primal variable count: 156
# Inferred dual variable count: 36
# LP constructed, initiated optimizer.
# MOSEK error 1001: The license has expired.
#
# *** A FLEXlm error occurred. FLEXlm reported:
#
# Feature has expired.
# Feature:       PTS
# Expire date:   23-jan-2021
# License path:  C:\Users\elupu\mosek\mosek.lic;
# FlexNet Licensing error:-10,32
#
# *** end of FLEXlm report.
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-20-60f3a3e717f5> in <module>
#      12 Sol=InfeasibilityCertificateAUTO(
#      13     SparseInflationMatrix,
# ---> 14     MarginalVector)
#      15
#
# D:\OneDrive\Github\CausInf\inflation\mosekinfeas.py in InfeasibilityCertificateAUTO(A, b, refine_subproblem)
#      94
#      95             # Optimize the task
# ---> 96             task.optimize()
#      97             # task.writejsonsol('mosek_sol.json')
#      98
#
# ~\anaconda3\envs\idp\lib\site-packages\mosek\__init__.py in optimize(self)
#    7625       if res != 0:
#    7626         result,msg = self.__getlasterror(res)
# -> 7627         raise Error(rescode(res),msg)
#    7628       __arg1_trmcode_return_value = resargs
#    7629       __arg1_trmcode_return_value = rescode(__arg1_trmcode_return_value)
#
# Error: rescode.err_license_expired(1001): The license has expired.

# %%
np.dot(Sol['x'],MarginalVector)
# Out:
# 0.0

# %%
np.array(Sol['x'])
# Out:
# array([-0., -0., -0., ..., -0., -0., -0.])

# %%
import compileall
import sys
from lib.certificate import Inequality
compileall.compile_file("lib\\certificate.py",force=True)
importlib.reload(sys.modules['lib.certificate'])
solveroutputcleanedup=Inequality(Graph,inflation_order,card,
           SparseInflationMatrix,MarginalVector,Sol)

# %%
solveroutputcleanedup.keys()
# Out:
# dict_keys(['Order of variables', 'Raw rolver output', 'Inequality as string', 'Coefficients grouped by index', 'Coefficients grouped by symbol', 'Clean solver output', 'Symolic association'])

# %%
np.dot(solveroutputcleanedup['Clean solver output'],MarginalVector)
# Out:
# -0.028238945225843096

# %%
solveroutputcleanedup['Coefficients grouped by symbol']
# Out:
# defaultdict(list,
#             {'1': ['P(000)P(003)',
#               'P(000)P(011)',
#               'P(000)P(012)',
#               'P(000)P(013)',
#               'P(000)P(022)',
#               'P(000)P(023)',
#               'P(000)P(030)',
#               'P(000)P(032)',
#               'P(000)P(033)',
#               'P(000)P(101)',
#               'P(000)P(102)',
#               'P(000)P(103)',
#               'P(000)P(113)',
#               'P(000)P(120)',
#               'P(000)P(122)',
#               'P(000)P(123)',
#               'P(000)P(132)',
#               'P(000)P(133)',
#               'P(000)P(201)',
#               'P(000)P(203)',
#               'P(000)P(210)',
#               'P(000)P(211)',
#               'P(000)P(213)',
#               'P(000)P(220)',
#               'P(000)P(221)',
#               'P(000)P(222)',
#               'P(000)P(223)',
#               'P(000)P(230)',
#               'P(000)P(300)',
#               'P(000)P(301)',
#               'P(000)P(303)',
#               'P(000)P(311)',
#               'P(000)P(320)',
#               'P(000)P(330)',
#               'P(000)P(331)',
#               'P(000)P(332)',
#               'P(001)P(002)',
#               'P(001)P(003)',
#               'P(001)P(010)',
#               'P(001)P(011)',
#               'P(001)P(012)',
#               'P(001)P(013)',
#               'P(001)P(020)',
#               'P(001)P(022)',
#               'P(001)P(023)',
#               'P(001)P(030)',
#               'P(001)P(031)',
#               'P(001)P(032)',
#               'P(001)P(033)',
#               'P(001)P(100)',
#               'P(001)P(101)',
#               'P(001)P(102)',
#               'P(001)P(103)',
#               'P(001)P(111)',
#               'P(001)P(112)',
#               'P(001)P(113)',
#               'P(001)P(120)',
#               'P(001)P(121)',
#               'P(001)P(122)',
#               'P(001)P(123)',
#               'P(001)P(130)',
#               'P(001)P(132)',
#               'P(001)P(133)',
#               'P(001)P(200)',
#               'P(001)P(201)',
#               'P(001)P(202)',
#               'P(001)P(203)',
#               'P(001)P(210)',
#               'P(001)P(211)',
#               'P(001)P(212)',
#               'P(001)P(213)',
#               'P(001)P(220)',
#               'P(001)P(221)',
#               'P(001)P(222)',
#               'P(001)P(223)',
#               'P(001)P(230)',
#               'P(001)P(231)',
#               'P(001)P(232)',
#               'P(001)P(300)',
#               'P(001)P(301)',
#               'P(001)P(302)',
#               'P(001)P(303)',
#               'P(001)P(310)',
#               'P(001)P(311)',
#               'P(001)P(312)',
#               'P(001)P(313)',
#               'P(001)P(320)',
#               'P(001)P(321)',
#               'P(001)P(322)',
#               'P(001)P(330)',
#               'P(001)P(331)',
#               'P(001)P(332)',
#               'P(001)P(333)',
#               'P(002)P(003)',
#               'P(002)P(010)',
#               'P(002)P(011)',
#               'P(002)P(012)',
#               'P(002)P(013)',
#               'P(002)P(020)',
#               'P(002)P(021)',
#               'P(002)P(022)',
#               'P(002)P(023)',
#               'P(002)P(030)',
#               'P(002)P(031)',
#               'P(002)P(032)',
#               'P(002)P(033)',
#               'P(002)P(100)',
#               'P(002)P(101)',
#               'P(002)P(102)',
#               'P(002)P(103)',
#               'P(002)P(111)',
#               'P(002)P(112)',
#               'P(002)P(113)',
#               'P(002)P(120)',
#               'P(002)P(121)',
#               'P(002)P(122)',
#               'P(002)P(123)',
#               'P(002)P(130)',
#               'P(002)P(131)',
#               'P(002)P(132)',
#               'P(002)P(133)',
#               'P(002)P(200)',
#               'P(002)P(201)',
#               'P(002)P(203)',
#               'P(002)P(210)',
#               'P(002)P(211)',
#               'P(002)P(212)',
#               'P(002)P(213)',
#               'P(002)P(220)',
#               'P(002)P(221)',
#               'P(002)P(222)',
#               'P(002)P(223)',
#               'P(002)P(230)',
#               'P(002)P(231)',
#               'P(002)P(232)',
#               'P(002)P(300)',
#               'P(002)P(301)',
#               'P(002)P(302)',
#               'P(002)P(303)',
#               'P(002)P(310)',
#               'P(002)P(311)',
#               'P(002)P(313)',
#               'P(002)P(320)',
#               'P(002)P(321)',
#               'P(002)P(322)',
#               'P(002)P(323)',
#               'P(002)P(330)',
#               'P(002)P(331)',
#               'P(002)P(332)',
#               'P(002)P(333)',
#               'P(003)P(010)',
#               'P(003)P(011)',
#               'P(003)P(012)',
#               'P(003)P(013)',
#               'P(003)P(020)',
#               'P(003)P(021)',
#               'P(003)P(022)',
#               'P(003)P(023)',
#               'P(003)P(030)',
#               'P(003)P(031)',
#               'P(003)P(032)',
#               'P(003)P(033)',
#               'P(003)P(100)',
#               'P(003)P(101)',
#               'P(003)P(102)',
#               'P(003)P(103)',
#               'P(003)P(110)',
#               'P(003)P(111)',
#               'P(003)P(112)',
#               'P(003)P(113)',
#               'P(003)P(120)',
#               'P(003)P(121)',
#               'P(003)P(122)',
#               'P(003)P(123)',
#               'P(003)P(130)',
#               'P(003)P(131)',
#               'P(003)P(132)',
#               'P(003)P(133)',
#               'P(003)P(200)',
#               'P(003)P(201)',
#               'P(003)P(202)',
#               'P(003)P(203)',
#               'P(003)P(210)',
#               'P(003)P(211)',
#               'P(003)P(212)',
#               'P(003)P(213)',
#               'P(003)P(220)',
#               'P(003)P(221)',
#               'P(003)P(222)',
#               'P(003)P(223)',
#               'P(003)P(230)',
#               'P(003)P(231)',
#               'P(003)P(232)',
#               'P(003)P(233)',
#               'P(003)P(300)',
#               'P(003)P(301)',
#               'P(003)P(302)',
#               'P(003)P(303)',
#               'P(003)P(310)',
#               'P(003)P(311)',
#               'P(003)P(312)',
#               'P(003)P(313)',
#               'P(003)P(320)',
#               'P(003)P(321)',
#               'P(003)P(322)',
#               'P(003)P(323)',
#               'P(003)P(330)',
#               'P(003)P(331)',
#               'P(003)P(332)',
#               'P(003)P(333)',
#               'P(010)P(011)',
#               'P(010)P(012)',
#               'P(010)P(013)',
#               'P(010)P(020)',
#               'P(010)P(022)',
#               'P(010)P(023)',
#               'P(010)P(030)',
#               'P(010)P(032)',
#               'P(010)P(033)',
#               'P(010)P(101)',
#               'P(010)P(102)',
#               'P(010)P(103)',
#               'P(010)P(111)',
#               'P(010)P(112)',
#               'P(010)P(113)',
#               'P(010)P(120)',
#               'P(010)P(122)',
#               'P(010)P(123)',
#               'P(010)P(130)',
#               'P(010)P(132)',
#               'P(010)P(133)',
#               'P(010)P(200)',
#               'P(010)P(201)',
#               'P(010)P(203)',
#               'P(010)P(210)',
#               'P(010)P(211)',
#               'P(010)P(213)',
#               'P(010)P(220)',
#               'P(010)P(221)',
#               'P(010)P(222)',
#               'P(010)P(230)',
#               'P(010)P(231)',
#               'P(010)P(232)',
#               'P(010)P(300)',
#               'P(010)P(301)',
#               'P(010)P(303)',
#               'P(010)P(310)',
#               'P(010)P(311)',
#               'P(010)P(313)',
#               'P(010)P(320)',
#               'P(010)P(321)',
#               'P(010)P(322)',
#               'P(010)P(323)',
#               'P(010)P(330)',
#               'P(010)P(331)',
#               'P(010)P(332)',
#               'P(011)P(012)',
#               'P(011)P(013)',
#               'P(011)P(020)',
#               'P(011)P(021)',
#               'P(011)P(022)',
#               'P(011)P(023)',
#               'P(011)P(030)',
#               'P(011)P(031)',
#               'P(011)P(032)',
#               'P(011)P(033)',
#               'P(011)P(100)',
#               'P(011)P(101)',
#               'P(011)P(102)',
#               'P(011)P(103)',
#               'P(011)P(110)',
#               'P(011)P(111)',
#               'P(011)P(112)',
#               'P(011)P(113)',
#               'P(011)P(120)',
#               'P(011)P(121)',
#               'P(011)P(122)',
#               'P(011)P(123)',
#               'P(011)P(130)',
#               'P(011)P(131)',
#               'P(011)P(132)',
#               'P(011)P(133)',
#               'P(011)P(200)',
#               'P(011)P(201)',
#               'P(011)P(202)',
#               'P(011)P(203)',
#               'P(011)P(210)',
#               'P(011)P(211)',
#               'P(011)P(212)',
#               'P(011)P(213)',
#               'P(011)P(220)',
#               'P(011)P(221)',
#               'P(011)P(222)',
#               'P(011)P(223)',
#               'P(011)P(230)',
#               'P(011)P(231)',
#               'P(011)P(232)',
#               'P(011)P(233)',
#               'P(011)P(300)',
#               'P(011)P(301)',
#               'P(011)P(302)',
#               'P(011)P(303)',
#               'P(011)P(310)',
#               'P(011)P(311)',
#               'P(011)P(312)',
#               'P(011)P(313)',
#               'P(011)P(320)',
#               'P(011)P(321)',
#               'P(011)P(322)',
#               'P(011)P(323)',
#               'P(011)P(330)',
#               'P(011)P(331)',
#               'P(011)P(332)',
#               'P(011)P(333)',
#               'P(012)P(013)',
#               'P(012)P(020)',
#               'P(012)P(021)',
#               'P(012)P(022)',
#               'P(012)P(023)',
#               'P(012)P(030)',
#               'P(012)P(031)',
#               'P(012)P(032)',
#               'P(012)P(033)',
#               'P(012)P(100)',
#               'P(012)P(101)',
#               'P(012)P(102)',
#               'P(012)P(103)',
#               'P(012)P(110)',
#               'P(012)P(111)',
#               'P(012)P(112)',
#               'P(012)P(113)',
#               'P(012)P(120)',
#               'P(012)P(121)',
#               'P(012)P(122)',
#               'P(012)P(123)',
#               'P(012)P(130)',
#               'P(012)P(131)',
#               'P(012)P(132)',
#               'P(012)P(133)',
#               'P(012)P(200)',
#               'P(012)P(201)',
#               'P(012)P(202)',
#               'P(012)P(203)',
#               'P(012)P(210)',
#               'P(012)P(211)',
#               'P(012)P(212)',
#               'P(012)P(213)',
#               'P(012)P(220)',
#               'P(012)P(221)',
#               'P(012)P(222)',
#               'P(012)P(223)',
#               'P(012)P(230)',
#               'P(012)P(231)',
#               'P(012)P(232)',
#               'P(012)P(233)',
#               'P(012)P(300)',
#               'P(012)P(301)',
#               'P(012)P(302)',
#               'P(012)P(303)',
#               'P(012)P(310)',
#               'P(012)P(311)',
#               'P(012)P(312)',
#               'P(012)P(313)',
#               'P(012)P(320)',
#               'P(012)P(321)',
#               'P(012)P(322)',
#               'P(012)P(323)',
#               'P(012)P(330)',
#               'P(012)P(331)',
#               'P(012)P(332)',
#               'P(012)P(333)',
#               'P(013)P(020)',
#               'P(013)P(021)',
#               'P(013)P(022)',
#               'P(013)P(023)',
#               'P(013)P(030)',
#               'P(013)P(031)',
#               'P(013)P(032)',
#               'P(013)P(033)',
#               'P(013)P(100)',
#               'P(013)P(101)',
#               'P(013)P(102)',
#               'P(013)P(103)',
#               'P(013)P(110)',
#               'P(013)P(111)',
#               'P(013)P(112)',
#               'P(013)P(113)',
#               'P(013)P(120)',
#               'P(013)P(121)',
#               'P(013)P(122)',
#               'P(013)P(123)',
#               'P(013)P(130)',
#               'P(013)P(131)',
#               'P(013)P(132)',
#               'P(013)P(133)',
#               'P(013)P(200)',
#               'P(013)P(201)',
#               'P(013)P(202)',
#               'P(013)P(203)',
#               'P(013)P(210)',
#               'P(013)P(211)',
#               'P(013)P(212)',
#               'P(013)P(213)',
#               'P(013)P(220)',
#               'P(013)P(221)',
#               'P(013)P(222)',
#               'P(013)P(223)',
#               'P(013)P(230)',
#               'P(013)P(231)',
#               'P(013)P(232)',
#               'P(013)P(233)',
#               'P(013)P(300)',
#               'P(013)P(301)',
#               'P(013)P(302)',
#               'P(013)P(303)',
#               'P(013)P(310)',
#               'P(013)P(311)',
#               'P(013)P(312)',
#               'P(013)P(313)',
#               'P(013)P(320)',
#               'P(013)P(321)',
#               'P(013)P(322)',
#               'P(013)P(323)',
#               'P(013)P(330)',
#               'P(013)P(331)',
#               'P(013)P(332)',
#               'P(013)P(333)',
#               'P(020)P(022)',
#               'P(020)P(023)',
#               'P(020)P(030)',
#               'P(020)P(031)',
#               'P(020)P(032)',
#               'P(020)P(033)',
#               'P(020)P(100)',
#               'P(020)P(101)',
#               'P(020)P(102)',
#               'P(020)P(103)',
#               'P(020)P(111)',
#               'P(020)P(112)',
#               'P(020)P(113)',
#               'P(020)P(120)',
#               'P(020)P(121)',
#               'P(020)P(122)',
#               'P(020)P(123)',
#               'P(020)P(130)',
#               'P(020)P(132)',
#               'P(020)P(133)',
#               'P(020)P(200)',
#               'P(020)P(201)',
#               'P(020)P(203)',
#               'P(020)P(210)',
#               'P(020)P(211)',
#               'P(020)P(212)',
#               'P(020)P(213)',
#               'P(020)P(220)',
#               'P(020)P(221)',
#               'P(020)P(222)',
#               'P(020)P(223)',
#               'P(020)P(230)',
#               'P(020)P(231)',
#               'P(020)P(232)',
#               'P(020)P(300)',
#               'P(020)P(301)',
#               'P(020)P(302)',
#               'P(020)P(303)',
#               'P(020)P(310)',
#               'P(020)P(311)',
#               'P(020)P(313)',
#               'P(020)P(320)',
#               'P(020)P(321)',
#               'P(020)P(322)',
#               'P(020)P(330)',
#               'P(020)P(331)',
#               'P(020)P(332)',
#               'P(020)P(333)',
#               'P(021)P(022)',
#               'P(021)P(030)',
#               'P(021)P(032)',
#               'P(021)P(033)',
#               'P(021)P(101)',
#               'P(021)P(102)',
#               'P(021)P(103)',
#               'P(021)P(112)',
#               'P(021)P(113)',
#               'P(021)P(120)',
#               'P(021)P(122)',
#               'P(021)P(123)',
#               'P(021)P(132)',
#               'P(021)P(133)',
#               'P(021)P(200)',
#               'P(021)P(201)',
#               'P(021)P(203)',
#               'P(021)P(210)',
#               'P(021)P(211)',
#               'P(021)P(212)',
#               'P(021)P(213)',
#               'P(021)P(220)',
#               'P(021)P(221)',
#               'P(021)P(222)',
#               'P(021)P(230)',
#               'P(021)P(300)',
#               'P(021)P(301)',
#               'P(021)P(302)',
#               'P(021)P(303)',
#               'P(021)P(310)',
#               'P(021)P(311)',
#               'P(021)P(320)',
#               'P(021)P(322)',
#               'P(021)P(330)',
#               'P(021)P(331)',
#               'P(021)P(332)',
#               'P(022)P(023)',
#               'P(022)P(030)',
#               'P(022)P(031)',
#               'P(022)P(032)',
#               'P(022)P(033)',
#               'P(022)P(100)',
#               'P(022)P(101)',
#               'P(022)P(102)',
#               'P(022)P(103)',
#               'P(022)P(110)',
#               'P(022)P(111)',
#               'P(022)P(112)',
#               'P(022)P(113)',
#               'P(022)P(120)',
#               'P(022)P(121)',
#               'P(022)P(122)',
#               'P(022)P(123)',
#               'P(022)P(130)',
#               'P(022)P(131)',
#               'P(022)P(132)',
#               'P(022)P(133)',
#               'P(022)P(200)',
#               'P(022)P(201)',
#               'P(022)P(202)',
#               'P(022)P(203)',
#               'P(022)P(210)',
#               'P(022)P(211)',
#               'P(022)P(212)',
#               'P(022)P(213)',
#               'P(022)P(220)',
#               'P(022)P(221)',
#               'P(022)P(222)',
#               'P(022)P(223)',
#               'P(022)P(230)',
#               'P(022)P(231)',
#               'P(022)P(232)',
#               'P(022)P(233)',
#               'P(022)P(300)',
#               'P(022)P(301)',
#               'P(022)P(302)',
#               'P(022)P(303)',
#               'P(022)P(310)',
#               'P(022)P(311)',
#               'P(022)P(312)',
#               'P(022)P(313)',
#               'P(022)P(320)',
#               'P(022)P(321)',
#               'P(022)P(322)',
#               'P(022)P(323)',
#               'P(022)P(330)',
#               'P(022)P(331)',
#               'P(022)P(332)',
#               'P(022)P(333)',
#               'P(023)P(030)',
#               'P(023)P(031)',
#               'P(023)P(032)',
#               'P(023)P(033)',
#               'P(023)P(100)',
#               'P(023)P(101)',
#               'P(023)P(102)',
#               'P(023)P(103)',
#               'P(023)P(110)',
#               'P(023)P(111)',
#               'P(023)P(112)',
#               'P(023)P(113)',
#               'P(023)P(120)',
#               'P(023)P(121)',
#               'P(023)P(122)',
#               'P(023)P(123)',
#               'P(023)P(130)',
#               'P(023)P(131)',
#               'P(023)P(132)',
#               'P(023)P(133)',
#               'P(023)P(200)',
#               'P(023)P(201)',
#               'P(023)P(202)',
#               'P(023)P(203)',
#               'P(023)P(210)',
#               'P(023)P(211)',
#               'P(023)P(212)',
#               'P(023)P(213)',
#               'P(023)P(220)',
#               'P(023)P(221)',
#               'P(023)P(222)',
#               'P(023)P(223)',
#               'P(023)P(230)',
#               'P(023)P(231)',
#               'P(023)P(232)',
#               'P(023)P(300)',
#               'P(023)P(301)',
#               'P(023)P(302)',
#               'P(023)P(303)',
#               'P(023)P(310)',
#               'P(023)P(311)',
#               'P(023)P(312)',
#               'P(023)P(313)',
#               'P(023)P(320)',
#               'P(023)P(321)',
#               'P(023)P(322)',
#               'P(023)P(330)',
#               'P(023)P(331)',
#               'P(023)P(332)',
#               'P(023)P(333)',
#               'P(030)P(031)',
#               'P(030)P(032)',
#               'P(030)P(033)',
#               'P(030)P(100)',
#               'P(030)P(101)',
#               'P(030)P(102)',
#               'P(030)P(103)',
#               'P(030)P(110)',
#               'P(030)P(111)',
#               'P(030)P(112)',
#               'P(030)P(113)',
#               'P(030)P(120)',
#               'P(030)P(121)',
#               'P(030)P(122)',
#               'P(030)P(123)',
#               'P(030)P(130)',
#               'P(030)P(131)',
#               'P(030)P(132)',
#               'P(030)P(133)',
#               'P(030)P(200)',
#               'P(030)P(201)',
#               'P(030)P(202)',
#               'P(030)P(203)',
#               'P(030)P(210)',
#               'P(030)P(211)',
#               'P(030)P(213)',
#               'P(030)P(220)',
#               'P(030)P(221)',
#               'P(030)P(222)',
#               'P(030)P(223)',
#               'P(030)P(230)',
#               'P(030)P(231)',
#               'P(030)P(232)',
#               'P(030)P(233)',
#               'P(030)P(300)',
#               'P(030)P(301)',
#               'P(030)P(303)',
#               'P(030)P(310)',
#               'P(030)P(311)',
#               'P(030)P(312)',
#               'P(030)P(313)',
#               'P(030)P(320)',
#               'P(030)P(321)',
#               'P(030)P(322)',
#               'P(030)P(323)',
#               'P(030)P(330)',
#               'P(030)P(331)',
#               'P(030)P(332)',
#               'P(030)P(333)',
#               'P(031)P(032)',
#               'P(031)P(033)',
#               'P(031)P(101)',
#               'P(031)P(102)',
#               'P(031)P(103)',
#               'P(031)P(111)',
#               'P(031)P(112)',
#               'P(031)P(113)',
#               'P(031)P(120)',
#               'P(031)P(122)',
#               'P(031)P(123)',
#               'P(031)P(130)',
#               'P(031)P(132)',
#               'P(031)P(133)',
#               'P(031)P(200)',
#               'P(031)P(201)',
#               'P(031)P(202)',
#               'P(031)P(203)',
#               'P(031)P(210)',
#               'P(031)P(211)',
#               'P(031)P(213)',
#               'P(031)P(220)',
#               'P(031)P(221)',
#               'P(031)P(222)',
#               'P(031)P(223)',
#               'P(031)P(230)',
#               'P(031)P(231)',
#               'P(031)P(232)',
#               'P(031)P(300)',
#               'P(031)P(301)',
#               'P(031)P(303)',
#               'P(031)P(310)',
#               'P(031)P(311)',
#               'P(031)P(312)',
#               'P(031)P(313)',
#               'P(031)P(320)',
#               'P(031)P(321)',
#               'P(031)P(322)',
#               'P(031)P(323)',
#               'P(031)P(330)',
#               'P(031)P(331)',
#               'P(031)P(332)',
#               'P(032)P(033)',
#               'P(032)P(100)',
#               'P(032)P(101)',
#               'P(032)P(102)',
#               'P(032)P(103)',
#               'P(032)P(110)',
#               'P(032)P(111)',
#               'P(032)P(112)',
#               'P(032)P(113)',
#               'P(032)P(120)',
#               'P(032)P(121)',
#               'P(032)P(122)',
#               'P(032)P(123)',
#               'P(032)P(130)',
#               'P(032)P(131)',
#               'P(032)P(132)',
#               'P(032)P(133)',
#               'P(032)P(200)',
#               'P(032)P(201)',
#               'P(032)P(202)',
#               'P(032)P(203)',
#               'P(032)P(210)',
#               'P(032)P(211)',
#               'P(032)P(212)',
#               'P(032)P(213)',
#               'P(032)P(220)',
#               'P(032)P(221)',
#               'P(032)P(222)',
#               'P(032)P(223)',
#               'P(032)P(230)',
#               'P(032)P(231)',
#               'P(032)P(232)',
#               'P(032)P(233)',
#               'P(032)P(300)',
#               'P(032)P(301)',
#               'P(032)P(302)',
#               'P(032)P(303)',
#               'P(032)P(310)',
#               'P(032)P(311)',
#               'P(032)P(312)',
#               'P(032)P(313)',
#               'P(032)P(320)',
#               'P(032)P(321)',
#               'P(032)P(322)',
#               'P(032)P(323)',
#               'P(032)P(330)',
#               'P(032)P(331)',
#               'P(032)P(332)',
#               'P(032)P(333)',
#               'P(033)P(100)',
#               'P(033)P(101)',
#               'P(033)P(102)',
#               'P(033)P(103)',
#               'P(033)P(110)',
#               'P(033)P(111)',
#               'P(033)P(112)',
#               'P(033)P(113)',
#               'P(033)P(120)',
#               'P(033)P(121)',
#               'P(033)P(122)',
#               'P(033)P(123)',
#               'P(033)P(130)',
#               'P(033)P(131)',
#               'P(033)P(132)',
#               'P(033)P(133)',
#               'P(033)P(200)',
#               'P(033)P(201)',
#               'P(033)P(202)',
#               'P(033)P(203)',
#               'P(033)P(210)',
#               'P(033)P(211)',
#               'P(033)P(212)',
#               'P(033)P(213)',
#               'P(033)P(220)',
#               'P(033)P(221)',
#               'P(033)P(222)',
#               'P(033)P(223)',
#               'P(033)P(230)',
#               'P(033)P(231)',
#               'P(033)P(232)',
#               'P(033)P(233)',
#               'P(033)P(300)',
#               'P(033)P(301)',
#               'P(033)P(302)',
#               'P(033)P(303)',
#               'P(033)P(310)',
#               'P(033)P(311)',
#               'P(033)P(312)',
#               'P(033)P(313)',
#               'P(033)P(320)',
#               'P(033)P(321)',
#               'P(033)P(322)',
#               'P(033)P(323)',
#               'P(033)P(330)',
#               'P(033)P(331)',
#               'P(033)P(332)',
#               'P(033)P(333)',
#               'P(100)P(101)',
#               'P(100)P(102)',
#               'P(100)P(103)',
#               'P(100)P(111)',
#               'P(100)P(112)',
#               'P(100)P(113)',
#               'P(100)P(120)',
#               'P(100)P(122)',
#               'P(100)P(123)',
#               'P(100)P(130)',
#               'P(100)P(132)',
#               'P(100)P(133)',
#               'P(100)P(200)',
#               'P(100)P(201)',
#               'P(100)P(210)',
#               'P(100)P(211)',
#               'P(100)P(213)',
#               'P(100)P(220)',
#               'P(100)P(221)',
#               'P(100)P(230)',
#               'P(100)P(231)',
#               'P(100)P(232)',
#               'P(100)P(233)',
#               'P(100)P(300)',
#               'P(100)P(301)',
#               'P(100)P(303)',
#               'P(100)P(310)',
#               'P(100)P(311)',
#               'P(100)P(313)',
#               'P(100)P(320)',
#               'P(100)P(321)',
#               'P(100)P(322)',
#               'P(100)P(323)',
#               'P(100)P(330)',
#               'P(100)P(331)',
#               'P(100)P(332)',
#               'P(101)P(102)',
#               'P(101)P(103)',
#               'P(101)P(110)',
#               'P(101)P(111)',
#               'P(101)P(112)',
#               'P(101)P(113)',
#               'P(101)P(120)',
#               'P(101)P(121)',
#               'P(101)P(122)',
#               'P(101)P(123)',
#               'P(101)P(130)',
#               'P(101)P(131)',
#               'P(101)P(132)',
#               'P(101)P(133)',
#               'P(101)P(200)',
#               'P(101)P(201)',
#               'P(101)P(202)',
#               'P(101)P(203)',
#               'P(101)P(210)',
#               'P(101)P(211)',
#               'P(101)P(212)',
#               'P(101)P(213)',
#               'P(101)P(220)',
#               'P(101)P(221)',
#               'P(101)P(222)',
#               'P(101)P(223)',
#               'P(101)P(230)',
#               'P(101)P(231)',
#               'P(101)P(232)',
#               'P(101)P(233)',
#               'P(101)P(300)',
#               'P(101)P(301)',
#               'P(101)P(302)',
#               'P(101)P(303)',
#               'P(101)P(310)',
#               'P(101)P(311)',
#               'P(101)P(312)',
#               'P(101)P(313)',
#               'P(101)P(320)',
#               'P(101)P(321)',
#               'P(101)P(322)',
#               'P(101)P(323)',
#               'P(101)P(330)',
#               'P(101)P(331)',
#               'P(101)P(332)',
#               'P(101)P(333)',
#               'P(102)P(103)',
#               'P(102)P(110)',
#               'P(102)P(111)',
#               'P(102)P(112)',
#               'P(102)P(113)',
#               'P(102)P(120)',
#               'P(102)P(121)',
#               'P(102)P(122)',
#               'P(102)P(123)',
#               'P(102)P(130)',
#               'P(102)P(131)',
#               'P(102)P(132)',
#               'P(102)P(133)',
#               'P(102)P(200)',
#               'P(102)P(201)',
#               'P(102)P(202)',
#               'P(102)P(203)',
#               'P(102)P(210)',
#               'P(102)P(211)',
#               'P(102)P(212)',
#               'P(102)P(213)',
#               'P(102)P(220)',
#               'P(102)P(221)',
#               'P(102)P(222)',
#               'P(102)P(223)',
#               'P(102)P(230)',
#               'P(102)P(231)',
#               'P(102)P(232)',
#               'P(102)P(233)',
#               'P(102)P(300)',
#               'P(102)P(301)',
#               'P(102)P(302)',
#               'P(102)P(303)',
#               'P(102)P(310)',
#               'P(102)P(311)',
#               'P(102)P(312)',
#               'P(102)P(313)',
#               'P(102)P(320)',
#               'P(102)P(321)',
#               'P(102)P(322)',
#               'P(102)P(323)',
#               'P(102)P(330)',
#               'P(102)P(331)',
#               'P(102)P(332)',
#               'P(102)P(333)',
#               'P(103)P(110)',
#               'P(103)P(111)',
#               'P(103)P(112)',
#               'P(103)P(113)',
#               'P(103)P(120)',
#               'P(103)P(121)',
#               'P(103)P(122)',
#               'P(103)P(123)',
#               'P(103)P(130)',
#               'P(103)P(131)',
#               'P(103)P(132)',
#               'P(103)P(133)',
#               'P(103)P(200)',
#               'P(103)P(201)',
#               'P(103)P(202)',
#               'P(103)P(203)',
#               'P(103)P(210)',
#               'P(103)P(211)',
#               'P(103)P(212)',
#               'P(103)P(213)',
#               'P(103)P(220)',
#               'P(103)P(221)',
#               'P(103)P(222)',
#               'P(103)P(223)',
#               'P(103)P(230)',
#               'P(103)P(231)',
#               'P(103)P(232)',
#               'P(103)P(233)',
#               'P(103)P(300)',
#               'P(103)P(301)',
#               'P(103)P(302)',
#               'P(103)P(303)',
#               'P(103)P(310)',
#               'P(103)P(311)',
#               'P(103)P(312)',
#               'P(103)P(313)',
#               'P(103)P(320)',
#               'P(103)P(321)',
#               'P(103)P(322)',
#               'P(103)P(323)',
#               'P(103)P(330)',
#               'P(103)P(331)',
#               'P(103)P(332)',
#               'P(103)P(333)',
#               'P(110)P(113)',
#               'P(110)P(120)',
#               'P(110)P(122)',
#               'P(110)P(123)',
#               'P(110)P(132)',
#               'P(110)P(201)',
#               'P(110)P(203)',
#               'P(110)P(210)',
#               'P(110)P(211)',
#               'P(110)P(213)',
#               'P(110)P(220)',
#               'P(110)P(221)',
#               'P(110)P(222)',
#               'P(110)P(223)',
#               'P(110)P(230)',
#               'P(110)P(300)',
#               'P(110)P(301)',
#               'P(110)P(303)',
#               'P(110)P(311)',
#               'P(110)P(313)',
#               'P(110)P(320)',
#               'P(110)P(330)',
#               'P(110)P(331)',
#               'P(110)P(332)',
#               'P(111)P(112)',
#               'P(111)P(113)',
#               'P(111)P(120)',
#               ...],
#              '-1': ['P(000)P(233)',
#               'P(000)P(323)',
#               'P(021)P(202)',
#               'P(021)P(233)',
#               'P(021)P(312)',
#               'P(021)P(333)',
#               'P(110)P(233)',
#               'P(110)P(323)',
#               'P(121)P(233)',
#               'P(131)P(202)'],
#              '2': ['P(010)P(223)',
#               'P(010)P(333)',
#               'P(030)P(212)',
#               'P(030)P(302)',
#               'P(100)P(203)',
#               'P(100)P(222)',
#               'P(100)P(223)',
#               'P(100)P(333)',
#               'P(121)P(212)',
#               'P(121)P(302)',
#               'P(130)P(223)'],
#              '3': ['P(031)P(212)', 'P(031)P(302)']})

# %%
solveroutputcleanedup['Raw rolver output']
# Out:
# [6.636913241209186e-13,
#  0.22682586044096542,
#  0.22682586044096542,
#  0.22682586044096542,
#  0.1504454788185834,
#  -0.49999999999556133,
#  0.1504454788185825,
#  0.1504454788185825,
#  0.11341293022048271,
#  0.22682586044096542,
#  0.22682586044096542,
#  0.4999999999966551,
#  0.15044547881858206,
#  0.4999999999996523,
#  0.4999999999996523,
#  0.11341293022048271,
#  0.22682586044096542,
#  0.4999999999996523,
#  0.15044547881858295,
#  0.4999999999996523,
#  0.4999999999966551,
#  0.11341293022048271,
#  0.4999999999996523,
#  0.15044547881858206,
#  0.4999999999966551,
#  0.4999999999996523,
#  0.11341293022048271,
#  0.22682586044096542,
#  0.22682586044096542,
#  0.22682586044096542,
#  6.636913241209186e-13,
#  0.22682586044096542,
#  0.22682586044096542,
#  0.11341293022048271,
#  0.22682586044096542,
#  0.11341293022048271]

# %%
# %run lib\moseklp.py
# Out:
# ['A', 'B', 'C']
# Inferred primal variable count: 2123776
# Inferred dual variable count: 2080
# LP constructed, initiated optimizer.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 2080
#   Cones                  : 0
#   Scalar variables       : 2123776
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Simplex optimizer started.
# Dual simplex optimizer started.
# Dual simplex optimizer setup started.
# Dual simplex optimizer setup terminated.
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 2080
# Optimizer  - Scalar variables       : 2123776           conic                  : 0
# Optimizer  - hotstart               : no
# ITER      DEGITER(%)  PFEAS       DFEAS       POBJ                  DOBJ                  TIME      TOTTIME
# 0         0.00        NA          0.00e+00    NA                    0.0000000000e+00      1.14      1.84
# 1000      2.40        NA          0.00e+00    NA                    1.8240988551e-01      4.17      4.88
# 2000      2.10        NA          0.00e+00    NA                    1.9763964564e-01      14.72     15.42
# 3000      2.60        NA          0.00e+00    NA                    2.0910463111e-01      29.25     29.95
# 4000      6.20        NA          0.00e+00    NA                    2.1883472135e-01      42.84     43.55
# 5000      9.58        NA          0.00e+00    NA                    2.3427201694e-01      54.22     54.92
