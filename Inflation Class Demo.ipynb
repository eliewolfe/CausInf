# %%
from __future__ import absolute_import
import numpy as np
from scipy.sparse import csr_matrix, coo_matrix
from itertools import combinations, chain, permutations
from igraph import Graph
from itertools import product
import json
from collections import defaultdict
from inflation.classestest import InflationLP,InflatedGraph

def ListOfBitStringsToListOfIntegers(list_of_bitstrings):
    return list(map(lambda s: int(s,4),list_of_bitstrings))
def UniformDistributionFromSupport(list_of_bitstrings):
    numvar = max(map(len,list_of_bitstrings))
    numevents = len(list_of_bitstrings)
    data = np.zeros(4 ** numvar)
    data[ListOfBitStringsToListOfIntegers(list_of_bitstrings)] = 1/numevents
    return data

def MixedCardinalityBaseConversion(cardinality, string):
    card=np.array([cardinality[i]**(len(cardinality)-(i+1)) for i in range(len(cardinality))])
    str_to_array=np.array([int(i) for i in string])
    return np.dot(card,str_to_array)
"""
import sys
sys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python37.zip')
sys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python3.7')
sys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python3.7/lib-dynload')
sys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python3.7/site-packages')
sys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python3.7/lib-dynload')
sys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python3.7/site-packages')
sys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions')
sys.path.remove('/Users/boraulu/opt/anaconda3/envs/myenv/lib/python38.zip')
sys.path.remove('/Users/boraulu/opt/anaconda3/envs/myenv/lib/python3.8')
sys.path.remove('/Users/boraulu/opt/anaconda3/envs/myenv/lib/python3.8/lib-dynload')
sys.path.remove('/Users/boraulu/opt/anaconda3/envs/myenv/lib/python3.8/site-packages')
sys.path.remove('/Users/boraulu/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/IPython/extensions')

import sys
print(sys.path)
print(np.__version__)
"""
# Out:
# "\nimport sys\nsys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python37.zip')\nsys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python3.7')\nsys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python3.7/lib-dynload')\nsys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python3.7/site-packages')\nsys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python3.7/lib-dynload')\nsys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python3.7/site-packages')\nsys.path.insert(0,'/Users/boraulu/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions')\nsys.path.remove('/Users/boraulu/opt/anaconda3/envs/myenv/lib/python38.zip')\nsys.path.remove('/Users/boraulu/opt/anaconda3/envs/myenv/lib/python3.8')\nsys.path.remove('/Users/boraulu/opt/anaconda3/envs/myenv/lib/python3.8/lib-dynload')\nsys.path.remove('/Users/boraulu/opt/anaconda3/envs/myenv/lib/python3.8/site-packages')\nsys.path.remove('/Users/boraulu/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/IPython/extensions')\n\nimport sys\nprint(sys.path)\nprint(np.__version__)\n"

# %%
InstrumentalGraph = Graph.Formula("U1->X->A->B,U2->A:B")
BiconfoundingGraph = Graph.Formula("U1->A:B,U2->A:C,A->B:C")
Evans14a = Graph.Formula("U1->A:C,U2->A:B:D,U3->B:C:D,A->B,C->D")
Evans14b = Graph.Formula("U1->A:C,U2->B:C:D,U3->A:D,A->B,B:C->D")
Evans14c = Graph.Formula("U1->A:C,U2->B:D,U3->A:D,A->B->C->D")
IceCreamGraph = Graph.Formula("U1->A,U2->B:D,U3->C:D,A->B:C,B->D")
BiconfoundingInstrumental = Graph.Formula("U1->A,U2->B:C,U3->B:D,A->B,B->C:D")
TriangleGraph = Graph.Formula("X->A,Y->A:B,Z->B:C,X->C")
BellGraph = Graph.Formula("L->A:B,Ux->X,Uy->Y,X->A,Y->B")

TriangleData=[0.12199995751046305, 0.0022969343799089472, 0.001748319476328954, 3.999015242496535e-05, 0.028907881434196828, 0.0005736087488455967, 0.0003924033706699725, 1.1247230369521505e-05, 0.0030142577390317635, 0.09234476010282468, 4.373922921480586e-05, 0.0014533921021948346, 0.0007798079722868244, 0.024091567451515063, 1.1247230369521505e-05, 0.0003849052170902915, 0.020774884184769502, 0.000396152447459813, 0.0003049249122403608, 4.998769053120669e-06, 0.10820335492385, 0.0020794879260981982, 0.0015546171755205281, 2.4993845265603346e-05, 0.0006260958239033638, 0.020273757587194154, 7.498153579681003e-06, 0.0003374169110856452, 0.0028942872817568676, 0.08976414557915113, 2.624353752888351e-05, 0.0012984302615480939, 0.002370666223442477, 4.7488306004646356e-05, 0.0999928767540993, 0.001957018084296742, 0.0006198473625869629, 8.747845842961171e-06, 0.02636975644747481, 0.0005198719815245496, 1.4996307159362007e-05, 0.000403650601039494, 0.0005498645958432735, 0.017359475229224805, 7.123245900696953e-05, 0.002346922070440154, 0.0033754188031197316, 0.10295964618712641, 0.00038740460161685187, 7.498153579681003e-06, 0.01608353942841575, 0.000306174604503641, 0.0021319750011559654, 4.248953695152569e-05, 0.09107007399427891, 0.001860791780024169, 5.998522863744803e-05, 0.0018395470115484063, 0.002570616985567304, 0.0766411271224461, 1.874538394920251e-05, 0.00048238121362614454, 0.0006410921310627258, 0.020223769896662948]
InstrumentalData=['000','011']
InstrumentalData2=['000']
BiconfoundingData=['000','011']
BiconfoundingInstrumentalData=['0000','0100','1011','1111']
Evans14aData=['0000','1001','1111']
Evans14aData2=['0000','0010','0101']
Evans14bData=['1000','1001','1111']
Evans14cData=['0000','1101','1011']
IceCreamData=['0000','1111','1010','0011']
A=list(product('0123',repeat=4))
B=[''.join(i) for i in A]
del B[0]
BellDataIncomp=B

BellData=['0000','0010','0001','0020','0002','1011','0111','1100','1110','1101','1120','1102','0021','1121','0012','1112','0022','1122','0031','0131','0032','0132','0013','1013','0023','1023','0030','0130','0003','1003','0033','0133']
cardinality=[2,2,4,4]
original_card_product=np.prod(cardinality)
NonlBellData = np.zeros(original_card_product)
NonlBellData[list(map(lambda s: MixedCardinalityBaseConversion(cardinality, s),BellData))] = 1/len(BellData)
NonlBellData[MixedCardinalityBaseConversion(cardinality, '0033')]=1/16
NonlBellData[MixedCardinalityBaseConversion(cardinality, '0133')]=0

# %%
rawgraph=InstrumentalGraph
rawdata=InstrumentalData

card=2
inflation_order=2
extra_ex=True
solver='moseklp'

InflatedGraph(rawgraph,inflation_order).print_assessment()
Output=InflationLP(rawgraph, rawdata, card, inflation_order,extra_ex,solver).Inequality()
# Out:
# For the graph who's parental structure is given by:
# ['U2:X->A', 'U2:A->B', 'U1->X']
# We utilize the following ordering of latent variables: [U1,U2]
# We utilize the following ordering of observed variables: [A,B,X]
# We identify the following screening-off relationships relevant to enforcing determinism:
# Sets given as (U1s,Ys,Xs) with the following meaning:	Ys are screened off from U1s by Xs.
# ([U1],[A],[X])
# ([U1],[B],[A])
# We identify the following screening-off non-ai expressible sets:
# Sets given as (Y,Xs,Zs,U3s) with the following meaning:
# Ys are screened off from Zs by Xs when U3s is different for (Y,Xs) vs Zs.
# ([A],[X],[B],[U2])
# ([B],[X],[A],[U2])
# For inflation order 2:
# The inflated diagonal expressible set is given by:
# [0 4 8 3 7 9]
# And we count 2 other expressible sets, namely:
# [0 5 8]
# [1 4 8]
# ────────────────────────────────────────────────────────────────────────────────
#
# Inferred primal variable count: 52
# Inferred dual variable count: 294
# LP constructed, initiated optimizer.
# Open file 'mosek_prob.jtask'
# Start writing.
# done writing. Time: 0.00
#
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 295
#   Cones                  : 0
#   Scalar variables       : 52
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 295
#   Cones                  : 0
#   Scalar variables       : 52
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 52
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 642               conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 1378              after factor           : 1378
# Factor     - dense dim.             : 0                 flops                  : 5.73e+04
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   7.3e+02  9.7e+00  4.2e+03  0.00e+00   -3.000000000e+00  -4.356761902e+02  9.5e+01  0.00
# 1   5.7e+02  7.5e+00  3.3e+03  6.19e-02   -2.311994987e+00  -3.439162470e+02  7.3e+01  0.03
# 2   2.7e+02  3.6e+00  1.6e+03  4.37e-01   -1.207799427e+00  -1.926246188e+02  3.5e+01  0.03
# 3   5.0e+01  6.6e-01  2.9e+02  9.66e-01   -1.464809703e-01  -3.882945342e+01  6.5e+00  0.03
# 4   3.9e+01  5.2e-01  2.2e+02  1.32e+00   -8.526222724e-02  -2.829542097e+01  5.0e+00  0.03
# 5   3.3e+00  4.4e-02  1.9e+01  1.26e+00   6.377573479e-02   -1.967882870e+00  4.3e-01  0.03
# 6   3.4e-01  4.6e-03  2.0e+00  1.03e+00   1.148027866e-02   -1.969579989e-01  4.5e-02  0.03
# 7   9.1e-02  2.1e-03  8.5e-01  1.00e+00   -9.248134937e-03  -9.778706944e-02  1.9e-02  0.03
# 8   2.2e-02  3.2e-04  1.8e-01  1.00e+00   -5.862337189e-02  -7.778902258e-02  3.8e-03  0.03
# 9   2.4e-04  3.4e-06  2.0e-03  1.00e+00   -6.239108568e-02  -6.259756062e-02  4.1e-05  0.04
# 10  1.2e-06  1.7e-08  1.0e-05  1.00e+00   -6.249944454e-02  -6.250049880e-02  2.1e-07  0.04
# 11  6.1e-09  4.0e-10  1.9e-08  1.00e+00   -6.249999717e-02  -6.249999913e-02  1.1e-09  0.04
# 12  6.1e-09  4.0e-10  1.9e-08  1.07e+00   -6.249999717e-02  -6.249999913e-02  1.1e-09  0.04
# Optimizer terminated. Time: 0.05
#
# Open file 'mosek_sol.json'
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: -6.2499997167e-02   nrm: 1e+00    Viol.  con: 5e-10    var: 0e+00
#   Dual.    obj: -6.2500004294e-02   nrm: 1e-01    Viol.  con: 4e-18    var: 0e+00
# Problem status: prosta.prim_and_dual_feas
# Solution status: solsta.optimal
#
# Coefficient Range: [-0.12499999462762601, 0.12499999532479333]
# Distribution Compatibility Status: INCOMPATIBLE
# Writing to file: 'inequality_output.json'

# %%
rawgraph=InstrumentalGraph
rawdata=InstrumentalData

card=[2,2,2]
inflation_order=2
extra_ex=True
solver='moseklp'

InflatedGraph(rawgraph,inflation_order).print_assessment()
Output=InflationLP(rawgraph, rawdata, card, inflation_order,extra_ex,solver).Inequality()
# Out:
# For the graph who's parental structure is given by:
# ['U2:X->A', 'U2:A->B', 'U1->X']
# We utilize the following ordering of latent variables: [U1,U2]
# We utilize the following ordering of observed variables: [A,B,X]
# We identify the following screening-off relationships relevant to enforcing determinism:
# Sets given as (U1s,Ys,Xs) with the following meaning:	Ys are screened off from U1s by Xs.
# ([U1],[A],[X])
# ([U1],[B],[A])
# We identify the following screening-off non-ai expressible sets:
# Sets given as (Y,Xs,Zs,U3s) with the following meaning:
# Ys are screened off from Zs by Xs when U3s is different for (Y,Xs) vs Zs.
# ([A],[X],[B],[U2])
# ([B],[X],[A],[U2])
# For inflation order 2:
# The inflated diagonal expressible set is given by:
# [0 4 8 3 7 9]
# And we count 2 other expressible sets, namely:
# [0 5 8]
# [1 4 8]
# ────────────────────────────────────────────────────────────────────────────────
#
# Inferred primal variable count: 52
# Inferred dual variable count: 294
# LP constructed, initiated optimizer.
# Open file 'mosek_prob.jtask'
# Start writing.
# done writing. Time: 0.00
#
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 295
#   Cones                  : 0
#   Scalar variables       : 52
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 295
#   Cones                  : 0
#   Scalar variables       : 52
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 52
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 642               conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 1378              after factor           : 1378
# Factor     - dense dim.             : 0                 flops                  : 5.73e+04
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   7.3e+02  9.7e+00  4.2e+03  0.00e+00   -3.000000000e+00  -4.356761902e+02  9.5e+01  0.00
# 1   5.7e+02  7.5e+00  3.3e+03  6.19e-02   -2.311994987e+00  -3.439162470e+02  7.3e+01  0.02
# 2   2.7e+02  3.6e+00  1.6e+03  4.37e-01   -1.207799427e+00  -1.926246188e+02  3.5e+01  0.02
# 3   5.0e+01  6.6e-01  2.9e+02  9.66e-01   -1.464809703e-01  -3.882945342e+01  6.5e+00  0.02
# 4   3.9e+01  5.2e-01  2.2e+02  1.32e+00   -8.526222724e-02  -2.829542097e+01  5.0e+00  0.03
# 5   3.3e+00  4.4e-02  1.9e+01  1.26e+00   6.377573479e-02   -1.967882870e+00  4.3e-01  0.03
# 6   3.4e-01  4.6e-03  2.0e+00  1.03e+00   1.148027866e-02   -1.969579989e-01  4.5e-02  0.03
# 7   9.1e-02  2.1e-03  8.5e-01  1.00e+00   -9.248134937e-03  -9.778706944e-02  1.9e-02  0.03
# 8   2.2e-02  3.2e-04  1.8e-01  1.00e+00   -5.862337189e-02  -7.778902258e-02  3.8e-03  0.03
# 9   2.4e-04  3.4e-06  2.0e-03  1.00e+00   -6.239108568e-02  -6.259756062e-02  4.1e-05  0.03
# 10  1.2e-06  1.7e-08  1.0e-05  1.00e+00   -6.249944454e-02  -6.250049880e-02  2.1e-07  0.03
# 11  6.1e-09  4.0e-10  1.9e-08  1.00e+00   -6.249999717e-02  -6.249999913e-02  1.1e-09  0.03
# 12  6.1e-09  4.0e-10  1.9e-08  1.07e+00   -6.249999717e-02  -6.249999913e-02  1.1e-09  0.03
# Optimizer terminated. Time: 0.05
#
# Open file 'mosek_sol.json'
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: -6.2499997167e-02   nrm: 1e+00    Viol.  con: 5e-10    var: 0e+00
#   Dual.    obj: -6.2500004294e-02   nrm: 1e-01    Viol.  con: 4e-18    var: 0e+00
# Problem status: prosta.prim_and_dual_feas
# Solution status: solsta.optimal
#
# Coefficient Range: [-0.12499999462762601, 0.12499999532479333]
# Distribution Compatibility Status: INCOMPATIBLE
# Writing to file: 'inequality_output.json'

# %%
rawgraph=InstrumentalGraph
rawdata=3

card=2
inflation_order=2
extra_ex=True
solver='moseklp'

InflatedGraph(rawgraph,inflation_order).print_assessment()
Output=InflationLP(rawgraph, rawdata, card, inflation_order,extra_ex,solver).Inequality()
# Out:
# For the graph who's parental structure is given by:
# ['U2:X->A', 'U2:A->B', 'U1->X']
# We utilize the following ordering of latent variables: [U1,U2]
# We utilize the following ordering of observed variables: [A,B,X]
# We identify the following screening-off relationships relevant to enforcing determinism:
# Sets given as (U1s,Ys,Xs) with the following meaning:	Ys are screened off from U1s by Xs.
# ([U1],[A],[X])
# ([U1],[B],[A])
# We identify the following screening-off non-ai expressible sets:
# Sets given as (Y,Xs,Zs,U3s) with the following meaning:
# Ys are screened off from Zs by Xs when U3s is different for (Y,Xs) vs Zs.
# ([A],[X],[B],[U2])
# ([B],[X],[A],[U2])
# For inflation order 2:
# The inflated diagonal expressible set is given by:
# [0 4 8 3 7 9]
# And we count 2 other expressible sets, namely:
# [0 5 8]
# [1 4 8]
# ────────────────────────────────────────────────────────────────────────────────
#
# Inferred primal variable count: 52
# Inferred dual variable count: 294
# LP constructed, initiated optimizer.
# Open file 'mosek_prob.jtask'
# Start writing.
# done writing. Time: 0.00
#
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 295
#   Cones                  : 0
#   Scalar variables       : 52
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 295
#   Cones                  : 0
#   Scalar variables       : 52
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 52
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 642               conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 1378              after factor           : 1378
# Factor     - dense dim.             : 0                 flops                  : 5.73e+04
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.6e+02  8.8e+00  3.8e+03  0.00e+00   -3.000000000e+00  -4.356761902e+02  7.8e+01  0.00
# 1   5.1e+02  6.8e+00  3.0e+03  6.19e-02   -2.307507347e+00  -3.439309631e+02  6.1e+01  0.02
# 2   2.4e+02  3.2e+00  1.4e+03  4.37e-01   -1.200262944e+00  -1.925979971e+02  2.9e+01  0.02
# 3   4.5e+01  6.0e-01  2.6e+02  9.66e-01   -1.402395044e-01  -3.884050011e+01  5.3e+00  0.02
# 4   3.5e+01  4.6e-01  2.0e+02  1.32e+00   -7.551886165e-02  -2.807894850e+01  4.1e+00  0.02
# 5   3.0e+00  3.9e-02  1.7e+01  1.26e+00   8.446800998e-02   -1.920377522e+00  3.5e-01  0.03
# 6   2.1e-01  2.8e-03  1.2e+00  1.04e+00   9.218045657e-02   -4.878678295e-02  2.5e-02  0.03
# 7   9.8e-02  3.7e-04  4.6e-01  1.00e+00   3.615768084e-02   -1.698099136e-02  7.6e-03  0.03
# 8   8.2e-04  1.3e-05  1.2e-02  1.00e+00   1.693142916e-02   1.560700734e-02   1.9e-04  0.03
# 9   4.3e-06  6.8e-08  6.1e-05  1.00e+00   1.563184243e-02   1.562484572e-02   1.0e-06  0.03
# 10  2.2e-08  5.8e-10  3.1e-07  1.00e+00   1.562503531e-02   1.562499948e-02   5.3e-09  0.03
# 11  1.1e-10  1.2e-09  1.3e-07  1.00e+00   1.562500018e-02   1.562498509e-02   2.7e-11  0.03
# 12  1.1e-10  1.2e-09  1.3e-07  2.24e+01   1.562500018e-02   1.562498509e-02   2.7e-11  0.03
# Optimizer terminated. Time: 0.05
#
# Open file 'mosek_sol.json'
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 1.5625000180e-02    nrm: 1e+00    Viol.  con: 9e-12    var: 0e+00
#   Dual.    obj: 1.5624999674e-02    nrm: 2e-02    Viol.  con: 2e-19    var: 3e-10
# Problem status: prosta.prim_and_dual_feas
# Solution status: solsta.optimal
#
# Coefficient Range: [3.1041835768519377e-12, 0.12506694816010677]
# Distribution Compatibility Status: COMPATIBLE
# Compatibility Error: The input distribution is compatible with given inflation order test.

# %%
rawgraph=TriangleGraph
rawdata=TriangleData

card=4
inflation_order=2
extra_ex=True
solver='moseklp'

InflatedGraph(rawgraph,inflation_order).print_assessment()
Output=InflationLP(rawgraph, rawdata, card, inflation_order,extra_ex,solver).Inequality()
# Out:
# For the graph who's parental structure is given by:
# ['X:Y->A', 'Y:Z->B', 'X:Z->C']
# We utilize the following ordering of latent variables: [X,Y,Z]
# We utilize the following ordering of observed variables: [A,B,C]
# We identify the following screening-off relationships relevant to enforcing determinism:
# Sets given as (U1s,Ys,Xs) with the following meaning:	Ys are screened off from U1s by Xs.
# We identify the following screening-off non-ai expressible sets:
# Sets given as (Y,Xs,Zs,U3s) with the following meaning:
# Ys are screened off from Zs by Xs when U3s is different for (Y,Xs) vs Zs.
# For inflation order 2:
# The inflated diagonal expressible set is given by:
# [ 0  4  8  3  7 11]
# And we count 0 other expressible sets, namely:
# ────────────────────────────────────────────────────────────────────────────────
#
# Inferred primal variable count: 2080
# Inferred dual variable count: 2123776
# LP constructed, initiated optimizer.
# Open file 'mosek_prob.jtask'
# Start writing.
# done writing. Time: 1.86
#
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 2123777
#   Cones                  : 0
#   Scalar variables       : 2080
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 2123777
#   Cones                  : 0
#   Scalar variables       : 2080
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 2080
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 4249634           conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 4.01              dense det. time        : 0.00
# Factor     - ML order time          : 0.06              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.16e+06          after factor           : 2.16e+06
# Factor     - dense dim.             : 0                 flops                  : 3.06e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   2.7e+05  6.5e+01  2.1e+08  0.00e+00   -1.000000000e+00  -3.231762005e+06  4.2e+03  6.37
# 1   2.7e+05  6.5e+01  2.1e+08  1.42e+00   -9.956087516e-01  -3.218328249e+06  4.2e+03  7.66
# 2   2.5e+05  5.9e+01  1.9e+08  3.07e-01   -9.394054572e-01  -3.035274070e+06  3.8e+03  9.32
# 3   2.5e+05  5.9e+01  1.9e+08  3.34e-01   -9.390713308e-01  -3.034194765e+06  3.8e+03  10.22
# 4   2.5e+05  5.9e+01  1.9e+08  3.35e-01   -9.386377671e-01  -3.032794524e+06  3.8e+03  11.08
# 5   2.2e+05  5.3e+01  1.7e+08  3.35e-01   -8.746251091e-01  -2.826117050e+06  3.5e+03  12.11
# 6   2.0e+05  4.9e+01  1.6e+08  4.01e-01   -8.243996108e-01  -2.663319268e+06  3.2e+03  13.54
# 7   1.8e+05  4.4e+01  1.4e+08  4.33e-01   -7.565437565e-01  -2.443572064e+06  2.8e+03  14.86
# 8   1.8e+05  4.4e+01  1.4e+08  4.84e-01   -7.546233788e-01  -2.437357788e+06  2.8e+03  15.75
# 9   1.7e+05  4.2e+01  1.4e+08  4.75e-01   -7.307973845e-01  -2.361481833e+06  2.7e+03  16.44
# 10  7.4e+03  1.8e+00  5.8e+06  4.87e-01   -3.856403421e-02  -1.285539970e+05  1.2e+02  18.23
# 11  8.0e+02  1.9e-01  6.2e+05  1.21e+00   -2.902924249e-03  -1.144155605e+04  1.2e+01  18.94
# 12  2.8e+01  9.8e-03  3.1e+04  2.07e+00   4.999506171e-04   -3.668166641e+02  6.2e-01  19.68
# 13  1.5e-01  2.9e-04  1.6e+02  1.01e+00   5.782682473e-04   -1.857730272e+00  3.2e-03  20.44
# 14  7.6e-04  1.0e-05  2.1e+00  1.00e+00   4.827905832e-04   -2.448247576e-02  4.0e-05  21.32
# 15  7.6e-04  1.0e-05  2.1e+00  1.00e+00   4.827905832e-04   -2.448247576e-02  4.0e-05  21.99
# 16  2.1e-04  2.7e-06  5.8e-01  1.00e+00   1.163013892e-04   -6.707804576e-03  1.1e-05  26.66
# 17  8.4e-05  1.1e-06  2.3e-01  1.00e+00   3.720062428e-05   -2.725656249e-03  4.5e-06  32.49
# 18  2.4e-05  3.1e-07  6.6e-02  1.00e+00   -6.104490357e-06  -7.896010969e-04  1.3e-06  37.55
# 19  9.9e-06  1.3e-07  2.7e-02  1.00e+00   -2.608275653e-05  -3.504331095e-04  5.3e-07  43.22
# 20  9.9e-06  1.3e-07  2.7e-02  -6.34e-01  -2.608275653e-05  -3.504331095e-04  5.3e-07  44.49
# 21  7.6e-06  1.0e-07  2.1e-02  1.00e+00   -3.219412583e-05  -2.815925520e-04  4.0e-07  45.96
# 22  7.6e-06  1.0e-07  2.1e-02  1.07e+00   -3.219412583e-05  -2.815925520e-04  4.0e-07  46.99
# 23  6.2e-06  8.1e-08  1.7e-02  1.00e+00   -3.638279079e-05  -2.404327885e-04  3.3e-07  48.22
# 24  6.2e-06  8.1e-08  1.7e-02  1.07e+00   -3.638279079e-05  -2.404327885e-04  3.3e-07  49.24
# 25  5.2e-06  6.8e-08  1.4e-02  1.00e+00   -3.991413034e-05  -2.090359416e-04  2.7e-07  50.50
# 26  4.9e-06  9.6e-08  1.2e-02  9.94e-01   -4.124194091e-05  -1.837358809e-04  2.6e-07  51.61
# 27  3.9e-06  7.7e-08  9.7e-03  1.00e+00   -4.481645339e-05  -1.583503404e-04  2.1e-07  52.99
# 28  3.9e-06  7.5e-08  9.6e-03  1.00e+00   -4.502067227e-05  -1.569157596e-04  2.0e-07  54.37
# 29  3.4e-06  6.7e-08  8.6e-03  1.00e+00   -4.662914186e-05  -1.464143109e-04  1.8e-07  55.62
# 30  3.1e-06  6.0e-08  7.7e-03  1.00e+00   -4.803514251e-05  -1.374266242e-04  1.6e-07  57.04
# 31  2.7e-06  5.4e-08  6.8e-03  1.00e+00   -4.936451874e-05  -1.290858574e-04  1.5e-07  58.43
# 32  2.7e-06  5.3e-08  6.7e-03  1.00e+00   -4.955768038e-05  -1.277565164e-04  1.4e-07  59.63
# 33  2.2e-06  4.3e-08  5.5e-03  1.00e+00   -5.160414041e-05  -1.154486488e-04  1.2e-07  61.07
# 34  1.8e-06  3.4e-08  4.4e-03  1.00e+00   -5.349229986e-05  -1.045468686e-04  9.3e-08  62.47
# 35  1.3e-06  2.5e-08  3.1e-03  1.00e+00   -5.572501500e-05  -9.214664188e-05  6.7e-08  63.85
# 36  9.7e-07  1.9e-08  2.4e-03  1.00e+00   -5.700877286e-05  -8.526723541e-05  5.2e-08  65.28
# 37  4.6e-07  9.1e-09  1.2e-03  1.00e+00   -5.943602984e-05  -7.289539064e-05  2.5e-08  66.67
# 38  2.5e-07  5.0e-09  6.3e-04  1.00e+00   -6.042660860e-05  -6.780366432e-05  1.4e-08  67.99
# 39  2.5e-07  5.0e-09  6.3e-04  9.99e-01   -6.042660860e-05  -6.780366432e-05  1.4e-08  69.10
# 40  1.8e-07  3.4e-09  4.4e-04  1.00e+00   -6.080574923e-05  -6.591829035e-05  9.4e-09  70.51
# Optimizer terminated. Time: 71.16
#
# Open file 'mosek_sol.json'
#
# Interior-point solution summary
#   Problem status  : UNKNOWN
#   Solution status : UNKNOWN
#   Primal.  obj: -6.0805749233e-05   nrm: 1e+00    Viol.  con: 1e-09    var: 0e+00
#   Dual.    obj: -6.6199510767e-05   nrm: 3e-03    Viol.  con: 2e-19    var: 0e+00
# Problem status: prosta.unknown
# Solution status: solsta.unknown
#
# Coefficient Range: [-0.0025331751972612615, 0.005068608009113129]
# Distribution Compatibility Status: INCOMPATIBLE
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-9a8845e81bc0> in <module>
#       8
#       9 InflatedGraph(rawgraph,inflation_order).print_assessment()
# ---> 10 Output=InflationLP(rawgraph, rawdata, card, inflation_order,extra_ex,solver).Inequality()
#
# ~/Desktop/repos/CausInf/inflation/classestest.py in Inequality(self)
#     761                 symboltally[i] = np.take(self.symbolic_b,vals).tolist()
#     762
# --> 763             final_ineq_WITHOUT_ZEROS = np.multiply(y[np.nonzero(y)], sy.symbols(' '.join(np.take(self.symbolic_b,np.nonzero(y))[0])))
#     764
#     765             Inequality_as_string = '0<=' + "+".join([str(term) for term in final_ineq_WITHOUT_ZEROS]).replace('*P', 'P').replace('2P','P')
#
# ~/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/sympy/core/symbol.py in symbols(names, cls, **args)
#     684             names = names[:-1].rstrip()
#     685         if not names:
# --> 686             raise ValueError('no symbols given')
#     687
#     688         # split on commas
#
# ValueError: no symbols given

# %%
rawgraph=BiconfoundingGraph
rawdata=BiconfoundingData

card=2
inflation_order=2
extra_ex=True
solver='moseklp'

InflatedGraph(rawgraph,inflation_order).print_assessment()
Output=InflationLP(rawgraph, rawdata, card, inflation_order,extra_ex,solver).Inequality()
# Out:
# For the graph who's parental structure is given by:
# ['U1:U2->A', 'U1:A->B', 'U2:A->C']
# We utilize the following ordering of latent variables: [U1,U2]
# We utilize the following ordering of observed variables: [A,B,C]
# We identify the following screening-off relationships relevant to enforcing determinism:
# Sets given as (U1s,Ys,Xs) with the following meaning:	Ys are screened off from U1s by Xs.
# ([U2],[B],[A])
# ([U1],[C],[A])
# We identify the following screening-off non-ai expressible sets:
# Sets given as (Y,Xs,Zs,U3s) with the following meaning:
# Ys are screened off from Zs by Xs when U3s is different for (Y,Xs) vs Zs.
# For inflation order 2:
# The inflated diagonal expressible set is given by:
# [ 0  4  8  3  7 11]
# And we count 0 other expressible sets, namely:
# ────────────────────────────────────────────────────────────────────────────────
#
# Inferred primal variable count: 36
# Inferred dual variable count: 362
# LP constructed, initiated optimizer.
# Open file 'mosek_prob.jtask'
# Start writing.
# done writing. Time: 0.00
#
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 363
#   Cones                  : 0
#   Scalar variables       : 36
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 363
#   Cones                  : 0
#   Scalar variables       : 36
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 36
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 762               conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 666               after factor           : 666
# Factor     - dense dim.             : 0                 flops                  : 2.15e+04
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   4.3e+02  8.2e+00  3.7e+03  0.00e+00   -1.000000000e+00  -4.557838380e+02  6.7e+01  0.00
# 1   3.5e+02  6.8e+00  3.1e+03  2.68e-01   -7.667511077e-01  -3.599087828e+02  5.5e+01  0.02
# 2   5.4e+01  1.0e+00  4.7e+02  4.44e-01   -1.163158797e-01  -6.003868290e+01  8.4e+00  0.02
# 3   7.2e+00  1.4e-01  6.3e+01  1.33e+00   9.090788215e-03   -6.363665848e+00  1.1e+00  0.02
# 4   4.5e+00  8.5e-02  3.9e+01  1.09e+00   1.237993521e-02   -3.886330131e+00  7.0e-01  0.03
# 5   2.2e-01  4.2e-03  1.9e+00  1.07e+00   1.099206439e-02   -1.759806059e-01  3.5e-02  0.03
# 6   2.1e-02  7.0e-04  3.0e-01  1.00e+00   -1.734372770e-02  -4.617583765e-02  5.4e-03  0.03
# 7   3.3e-03  1.1e-04  4.6e-02  1.00e+00   -2.643233189e-02  -3.086720769e-02  8.3e-04  0.03
# 8   2.7e-05  8.7e-07  3.7e-04  1.00e+00   -2.776857844e-02  -2.780442886e-02  6.7e-06  0.03
# 9   1.4e-07  4.6e-09  1.9e-06  1.00e+00   -2.777773086e-02  -2.777791341e-02  3.4e-08  0.03
# 10  1.4e-07  4.6e-09  1.9e-06  9.73e-01   -2.777773086e-02  -2.777791341e-02  3.4e-08  0.03
# 11  7.3e-10  1.8e-09  3.4e-08  1.00e+00   -2.777777754e-02  -2.777777423e-02  1.7e-10  0.03
# Optimizer terminated. Time: 0.05
#
# Open file 'mosek_sol.json'
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: -2.7777777539e-02   nrm: 1e+00    Viol.  con: 5e-11    var: 0e+00
#   Dual.    obj: -2.7777778683e-02   nrm: 6e-02    Viol.  con: 2e-18    var: 6e-11
# Problem status: prosta.prim_and_dual_feas
# Solution status: solsta.optimal
#
# Coefficient Range: [-0.05555555509722798, 0.05555555543328716]
# Distribution Compatibility Status: INCOMPATIBLE
# Writing to file: 'inequality_output.json'

# %%
rawgraph=Evans14a
rawdata=Evans14aData

card=2
inflation_order=2
extra_ex=True
solver='moseklp'

InflatedGraph(rawgraph,inflation_order).print_assessment()
Output=InflationLP(rawgraph, rawdata, card, inflation_order,extra_ex,solver).Inequality()
# Out:
# For the graph who's parental structure is given by:
# ['U1:U2->A', 'U2:U3:A->B', 'U1:U3->C', 'U2:U3:C->D']
# We utilize the following ordering of latent variables: [U1,U2,U3]
# We utilize the following ordering of observed variables: [A,B,C,D]
# We identify the following screening-off relationships relevant to enforcing determinism:
# Sets given as (U1s,Ys,Xs) with the following meaning:	Ys are screened off from U1s by Xs.
# ([U1],[B],[A])
# ([U1],[D],[C])
# We identify the following screening-off non-ai expressible sets:
# Sets given as (Y,Xs,Zs,U3s) with the following meaning:
# Ys are screened off from Zs by Xs when U3s is different for (Y,Xs) vs Zs.
# ([B],[A],[C],[U3])
# ([D],[C],[A],[U2])
# For inflation order 2:
# The inflated diagonal expressible set is given by:
# [ 0  4 12 16  3 11 15 23]
# And we count 2 other expressible sets, namely:
# [ 0  4 13]
# [ 1 12 16]
# ────────────────────────────────────────────────────────────────────────────────
#
# Inferred primal variable count: 152
# Inferred dual variable count: 967536
# LP constructed, initiated optimizer.
# Open file 'mosek_prob.jtask'
# Start writing.
# done writing. Time: 0.99
#
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 967537
#   Cones                  : 0
#   Scalar variables       : 152
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 967537
#   Cones                  : 0
#   Scalar variables       : 152
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 152
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 1935226           conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 1.02              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 1.16e+04          after factor           : 1.16e+04
# Factor     - dense dim.             : 0                 flops                  : 8.68e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.2e+03  2.1e+01  3.8e+07  0.00e+00   -3.000000000e+00  -1.808903241e+06  4.5e+02  1.90
# 1   8.9e+03  2.0e+01  3.7e+07  1.09e+00   -2.873789340e+00  -1.737287112e+06  4.4e+02  2.19
# 2   8.9e+03  2.0e+01  3.7e+07  6.91e-01   -2.935171358e+00  -1.768358132e+06  4.4e+02  2.37
# 3   8.8e+03  2.0e+01  3.7e+07  7.81e-01   -2.867708487e+00  -1.733621830e+06  4.3e+02  2.56
# 4   6.3e+03  1.4e+01  2.6e+07  6.02e-01   -2.043327432e+00  -1.247606156e+06  3.1e+02  2.77
# 5   4.0e+03  9.2e+00  1.7e+07  6.93e-01   -1.303072519e+00  -8.221620176e+05  2.0e+02  2.96
# 6   3.3e+02  7.5e-01  1.4e+06  8.41e-01   -1.567795896e-02  -7.026324785e+04  1.6e+01  3.16
# 7   3.7e+01  8.6e-02  1.5e+05  1.25e+00   7.211139883e-02   -6.980780324e+03  1.8e+00  3.36
# 8   2.1e-01  4.9e-04  8.9e+02  1.02e+00   8.204395649e-02   -3.961041696e+01  1.0e-02  3.56
# 9   1.1e-03  2.5e-05  4.2e+01  1.00e+00   7.663301629e-02   -1.817108441e+00  4.9e-04  3.75
# 10  5.6e-04  8.4e-04  8.7e+00  1.00e+00   3.364715567e-02   -3.526255528e-01  9.4e-05  3.95
# 11  5.5e-04  7.1e-04  8.4e+00  1.00e+00   3.493733079e-02   -3.381027158e-01  9.2e-05  4.14
# 12  4.5e-04  4.6e-04  4.5e+00  1.00e+00   2.587254984e-02   -1.735859364e-01  5.3e-05  4.34
# 13  4.5e-04  4.6e-04  4.5e+00  1.99e+00   2.587254984e-02   -1.735859364e-01  5.3e-05  4.60
# 14  1.1e-04  1.2e-04  1.1e+00  1.00e+00   2.722109601e-03   -4.789023947e-02  1.3e-05  5.12
# 15  4.5e-06  4.7e-06  4.5e-02  1.00e+00   9.970194651e-05   -1.924875649e-03  5.4e-07  5.69
# 16  6.8e-08  1.6e-06  1.3e-03  1.00e+00   5.534520988e-07   5.771677599e-05   3.1e-09  6.09
# 17  3.4e-10  8.3e-09  6.7e-06  1.00e+00   2.855937709e-09   2.978350992e-07   1.6e-11  6.60
# 18  9.3e-12  4.2e-11  3.4e-08  1.00e+00   1.456479382e-11   1.521981652e-09   8.1e-14  7.07
# Optimizer terminated. Time: 7.34
#
# Open file 'mosek_sol.json'
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 1.4564263376e-11    nrm: 1e+00    Viol.  con: 1e-13    var: 0e+00
#   Dual.    obj: -2.7977429671e-10   nrm: 3e-02    Viol.  con: 1e-18    var: 0e+00
# Problem status: prosta.prim_and_dual_feas
# Solution status: solsta.optimal
#
# Coefficient Range: [3.979039320256561e-13, 0.11170607721330206]
# Distribution Compatibility Status: COMPATIBLE
# Compatibility Error: The input distribution is compatible with given inflation order test.

# %%
rawgraph=Evans14b
rawdata=Evans14bData

card=2
inflation_order=2
extra_ex=True
solver='moseklp'

InflatedGraph(rawgraph,inflation_order).print_assessment()
Output=InflationLP(rawgraph, rawdata, card, inflation_order,extra_ex,solver).Inequality()
# Out:
# For the graph who's parental structure is given by:
# ['U1:U3->A', 'U2:A->B', 'U1:U2->C', 'U2:U3:B:C->D']
# We utilize the following ordering of latent variables: [U1,U2,U3]
# We utilize the following ordering of observed variables: [A,B,C,D]
# We identify the following screening-off relationships relevant to enforcing determinism:
# Sets given as (U1s,Ys,Xs) with the following meaning:	Ys are screened off from U1s by Xs.
# ([U1],[B],[A])
# ([U3],[B],[A])
# ([U1,U3],[B],[A])
# ([U1],[D],[B,C])
# We identify the following screening-off non-ai expressible sets:
# Sets given as (Y,Xs,Zs,U3s) with the following meaning:
# Ys are screened off from Zs by Xs when U3s is different for (Y,Xs) vs Zs.
# ([B],[A],[C],[U2])
# ([B],[A],[C,D],[U2])
# For inflation order 2:
# The inflated diagonal expressible set is given by:
# [ 0  4 12 16  3 11 15 23]
# And we count 2 other expressible sets, namely:
# [ 0  4 13]
# [ 0  4 13 18]
# ────────────────────────────────────────────────────────────────────────────────
#
# Inferred primal variable count: 160
# Inferred dual variable count: 187680
# LP constructed, initiated optimizer.
# Open file 'mosek_prob.jtask'
# Start writing.
# done writing. Time: 0.19
#
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 187681
#   Cones                  : 0
#   Scalar variables       : 160
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 187681
#   Cones                  : 0
#   Scalar variables       : 160
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 160
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 375522            conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.13              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 1.29e+04          after factor           : 1.29e+04
# Factor     - dense dim.             : 0                 flops                  : 3.79e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+04  2.2e+01  7.6e+06  0.00e+00   -3.000000000e+00  -3.477665784e+05  4.8e+02  0.29
# 1   9.7e+03  2.1e+01  7.4e+06  1.03e+00   -2.881554372e+00  -3.348488702e+05  4.7e+02  0.37
# 2   9.7e+03  2.1e+01  7.4e+06  5.48e-01   -2.925443644e+00  -3.388675082e+05  4.7e+02  0.42
# 3   9.6e+03  2.1e+01  7.3e+06  5.88e-01   -2.843188154e+00  -3.305021072e+05  4.6e+02  0.45
# 4   6.8e+03  1.5e+01  5.2e+06  5.21e-01   -2.014180941e+00  -2.366005294e+05  3.3e+02  0.49
# 5   1.6e+03  3.5e+00  1.2e+06  5.71e-01   -4.349225546e-01  -6.035810279e+04  7.6e+01  0.53
# 6   3.6e+02  8.0e-01  2.8e+05  9.43e-01   -4.891140745e-02  -1.348450923e+04  1.7e+01  0.57
# 7   6.7e+01  1.5e-01  5.1e+04  1.20e+00   3.894038171e-02   -2.258454044e+03  3.2e+00  0.61
# 8   9.5e-01  2.1e-03  7.3e+02  1.04e+00   5.633666494e-02   -3.110881679e+01  4.6e-02  0.65
# 9   4.9e-03  8.9e-05  3.1e+01  1.00e+00   5.038712502e-02   -1.276795739e+00  1.9e-03  0.69
# 10  3.1e-03  2.8e-05  1.0e+01  1.00e+00   1.745596707e-02   -4.160401680e-01  6.3e-04  0.73
# 11  2.3e-03  2.3e-05  7.9e+00  1.00e+00   1.400146043e-02   -3.249203030e-01  4.9e-04  0.77
# 12  1.7e-03  6.3e-04  6.7e+00  1.01e+00   1.120636781e-02   -2.735087212e-01  4.3e-04  0.81
# 13  7.9e-04  1.9e-03  3.2e+00  1.00e+00   4.919892318e-03   -1.265638871e-01  2.1e-04  0.85
# 14  7.9e-04  1.9e-03  3.2e+00  9.86e-01   4.919892318e-03   -1.265638871e-01  2.1e-04  0.89
# 15  1.8e-04  4.3e-04  7.1e-01  1.00e+00   9.239609712e-04   -2.848300856e-02  4.8e-05  0.98
# 16  1.4e-06  3.4e-06  5.7e-03  1.00e+00   7.280793750e-06   -2.288177835e-04  3.8e-07  1.07
# 17  7.2e-09  1.7e-08  2.9e-05  1.00e+00   3.712912999e-08   -1.166878537e-06  2.0e-09  1.15
# 18  3.3e-11  8.9e-11  1.5e-07  1.00e+00   1.893427637e-10   -5.950850923e-09  1.0e-11  1.25
# Optimizer terminated. Time: 1.30
#
# Open file 'mosek_sol.json'
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 1.8934325712e-10    nrm: 1e+00    Viol.  con: 4e-13    var: 0e+00
#   Dual.    obj: -6.2957199277e-09   nrm: 2e-02    Viol.  con: 2e-18    var: 3e-11
# Problem status: prosta.prim_and_dual_feas
# Solution status: solsta.optimal
#
# Coefficient Range: [2.3030466422824247e-12, 0.06720651429847457]
# Distribution Compatibility Status: COMPATIBLE
# Compatibility Error: The input distribution is compatible with given inflation order test.

# %%
rawgraph=Evans14c
rawdata=Evans14cData

card=2
inflation_order=2
extra_ex=True
solver='moseklp'

InflatedGraph(rawgraph,inflation_order).print_assessment()
Output=InflationLP(rawgraph, rawdata, card, inflation_order,extra_ex,solver).Inequality()
# Out:
# For the graph who's parental structure is given by:
# ['U1:U3->A', 'U2:A->B', 'U1:B->C', 'U2:U3:C->D']
# We utilize the following ordering of latent variables: [U1,U2,U3]
# We utilize the following ordering of observed variables: [A,B,C,D]
# We identify the following screening-off relationships relevant to enforcing determinism:
# Sets given as (U1s,Ys,Xs) with the following meaning:	Ys are screened off from U1s by Xs.
# ([U1],[B],[A])
# ([U3],[B],[A])
# ([U1,U3],[B],[A])
# ([U2],[C],[B])
# ([U3],[C],[B])
# ([U2,U3],[C],[B])
# ([U1],[D],[C])
# We identify the following screening-off non-ai expressible sets:
# Sets given as (Y,Xs,Zs,U3s) with the following meaning:
# Ys are screened off from Zs by Xs when U3s is different for (Y,Xs) vs Zs.
# ([B],[A],[C,D],[U2])
# For inflation order 2:
# The inflated diagonal expressible set is given by:
# [ 0  4 12 20  3 11 19 27]
# And we count 1 other expressible sets, namely:
# [ 0  4 14 22]
# ────────────────────────────────────────────────────────────────────────────────
#
# Inferred primal variable count: 152
# Inferred dual variable count: 71232
# LP constructed, initiated optimizer.
# Open file 'mosek_prob.jtask'
# Start writing.
# done writing. Time: 0.08
#
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 71233
#   Cones                  : 0
#   Scalar variables       : 152
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 71233
#   Cones                  : 0
#   Scalar variables       : 152
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 152
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 142618            conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.07              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 1.16e+04          after factor           : 1.16e+04
# Factor     - dense dim.             : 0                 flops                  : 2.47e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.2e+03  2.1e+01  2.9e+06  0.00e+00   -2.000000000e+00  -1.363194939e+05  4.5e+02  0.15
# 1   9.0e+03  2.1e+01  2.8e+06  8.87e-01   -1.918258278e+00  -1.310852183e+05  4.4e+02  0.20
# 2   8.6e+03  2.0e+01  2.7e+06  5.87e-01   -1.864255380e+00  -1.267863200e+05  4.2e+02  0.22
# 3   8.1e+03  1.9e+01  2.6e+06  5.40e-01   -1.723345079e+00  -1.180395046e+05  4.0e+02  0.24
# 4   4.9e+03  1.1e+01  1.5e+06  5.03e-01   -1.038733073e+00  -7.294706105e+04  2.4e+02  0.26
# 5   1.0e+03  2.3e+00  3.2e+05  5.26e-01   -2.131500630e-01  -1.768112441e+04  4.9e+01  0.34
# 6   1.4e+02  3.3e-01  4.5e+04  1.08e+00   1.912736223e-03   -2.253454824e+03  7.0e+00  0.37
# 7   3.6e+01  8.4e-02  1.1e+04  1.20e+00   2.496425246e-02   -5.311381648e+02  1.8e+00  0.39
# 8   2.4e+00  5.6e-03  7.6e+02  1.04e+00   3.149244915e-02   -3.459193215e+01  1.2e-01  0.41
# 9   1.2e-02  1.6e-04  2.2e+01  1.00e+00   2.911440641e-02   -9.593427276e-01  3.4e-03  0.44
# 10  8.7e-03  4.2e-05  6.3e+00  1.00e+00   1.048771961e-02   -2.754549348e-01  9.8e-04  0.46
# 11  6.8e-03  3.8e-05  5.7e+00  1.00e+00   8.935990430e-03   -2.487260053e-01  8.8e-04  0.48
# 12  4.5e-03  3.4e-05  5.1e+00  1.00e+00   1.158307499e-02   -2.215018306e-01  7.9e-04  0.50
# 13  3.9e-03  3.6e-05  4.9e+00  9.99e-01   1.128751119e-02   -2.143649337e-01  7.7e-04  0.52
# 14  1.5e-03  2.8e-05  3.7e+00  1.00e+00   3.067108702e-03   -1.669586344e-01  5.8e-04  0.54
# 15  4.1e-05  6.3e-06  8.2e-01  1.00e+00   1.019537409e-03   -3.631855418e-02  1.3e-04  0.56
# 16  4.1e-05  6.3e-06  8.2e-01  8.80e-01   1.019537409e-03   -3.631855418e-02  1.3e-04  0.58
# 17  4.6e-07  7.1e-08  9.2e-03  1.00e+00   1.199706160e-05   -4.094064548e-04  1.4e-06  0.63
# 18  2.4e-09  3.7e-10  4.8e-05  1.00e+00   6.190818347e-08   -2.112668753e-06  7.4e-09  0.66
# 19  2.4e-09  3.7e-10  4.8e-05  1.00e+00   6.190818347e-08   -2.112668753e-06  7.4e-09  0.70
# 20  1.0e-11  1.9e-12  2.5e-07  1.00e+00   3.194600140e-10   -1.090188073e-08  3.8e-11  0.74
# 21  4.8e-12  1.5e-14  1.3e-09  1.00e+00   1.629363311e-12   -5.554756655e-11  1.9e-13  0.78
# Optimizer terminated. Time: 0.81
#
# Open file 'mosek_sol.json'
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 1.6293633109e-12    nrm: 1e+00    Viol.  con: 5e-14    var: 0e+00
#   Dual.    obj: -5.6120061667e-11   nrm: 3e-02    Viol.  con: 2e-18    var: 0e+00
# Problem status: prosta.prim_and_dual_feas
# Solution status: solsta.optimal
#
# Coefficient Range: [4.796163466380676e-14, 0.04922521353536524]
# Distribution Compatibility Status: COMPATIBLE
# Compatibility Error: The input distribution is compatible with given inflation order test.
